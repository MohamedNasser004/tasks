# %%
from ultralytics import YOLO
import matplotlib.pyplot as plt
import cv2

# %%
model = YOLO("D:\cvvvv\segmentation\yolov8n-seg.pt")
results = model(r"C:\Users\Abo Nasser\Desktop\sec6\images\dog.jpg")
result_img = results[0].plot()
plt.imshow(result_img)
plt.axis('off')
plt.show()
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\c'
# <>:1: SyntaxWarning: invalid escape sequence '\c'
# C:\Users\Abo Nasser\AppData\Local\Temp\ipykernel_7212\86470898.py:1: SyntaxWarning: invalid escape sequence '\c'
#   model = YOLO("D:\cvvvv\segmentation\yolov8n-seg.pt")
# image 1/1 C:\Users\Abo Nasser\Desktop\sec6\images\dog.jpg: 480x640 1 bicycle, 1 car, 1 truck, 1 dog, 191.3ms
# Speed: 17.0ms preprocess, 191.3ms inference, 24.9ms postprocess per image at shape (1, 3, 480, 640)

# %%
from ultralytics import YOLO

model = YOLO("D:\\cvvvv\\segmentation\\yolov8n-seg.pt")

cap = cv2.VideoCapture("D:\\cvvvv\\segmentation\\dodge.mp4")

# Output video settings
out = cv2.VideoWriter("output_segment_Video.mp4",
                      cv2.VideoWriter_fourcc(*"mp4v"),
                      cap.get(cv2.CAP_PROP_FPS),
                      (int(cap.get(cv2.CAP_PROP_FRAME_WIDTH)),
                       int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))))
                      

while cap.isOpened():
    ret, frame = cap.read()
    if not ret:
        break
    result_img = model(frame)[0].plot()
    out.write(result_img)
    cv2.imshow("Processed Frame", result_img)

    if cv2.waitKey(1) == ord('q'):
        break

cap.release()
out.release()
cv2.destroyAllWindows()
